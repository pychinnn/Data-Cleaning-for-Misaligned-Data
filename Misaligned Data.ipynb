# %%
import pandas as pd

# %%
df = pd.read_excel('Misaligned Data.xls', engine="xlrd")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4698 entries, 0 to 4697
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               4618 non-null   object
#  1   Customer Outlet  90 non-null     object
#  2   Itemlink         4618 non-null   object
#  3   Itemcode         4618 non-null   object
#  4   Description      4618 non-null   object
#  5   Divdesc          4618 non-null   object
#  6   Deptdesc         4618 non-null   object
#  7   Subdeptdesc      4618 non-null   object
#  8   Categorydesc     4618 non-null   object
#  9   Creation Date    4618 non-null   object
#  10  Qty              4618 non-null   object
# dtypes: object(11)
# memory usage: 403.9+ KB

# %%
df = df[df['No'] != 'No']

df_1 = df.loc[:, ['No']]
df_2 = df.loc[:, ['Itemlink', 'Itemcode', 'Description']]
df_3 = df.loc[:, ['Divdesc', 'Deptdesc', 'Subdeptdesc', 'Categorydesc']]
df_4 = df.loc[:, ['Qty']]

df_1 = df_1.dropna().reset_index(drop=True)
df_2 = df_2.dropna().reset_index(drop=True)
df_3 = df_3.dropna().reset_index(drop=True)
df_4 = df_4.dropna().reset_index(drop=True)

df = pd.concat([df_1, df_2, df_3, df_4], axis=1)
df.to_excel('Misaligned Data R1.xlsx', index=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4528 entries, 0 to 4527
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No            4528 non-null   object
#  1   Itemlink      4528 non-null   object
#  2   Itemcode      4528 non-null   object
#  3   Description   4528 non-null   object
#  4   Divdesc       4528 non-null   object
#  5   Deptdesc      4528 non-null   object
#  6   Subdeptdesc   4528 non-null   object
#  7   Categorydesc  4528 non-null   object
#  8   Qty           4528 non-null   object
# dtypes: object(9)
# memory usage: 318.5+ KB
