# %%
import pandas as pd

# %%
df = pd.read_excel('Misaligned Data.xls', engine="xlrd")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12455 entries, 0 to 12454
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No                12237 non-null  object
#  1   Customer Code     12006 non-null  object
#  2   Customer Name     12237 non-null  object
#  3   Customer Outlet   231 non-null    object
#  4   Itemlink          12237 non-null  object
#  5   Itemcode          12237 non-null  object
#  6   Description       12237 non-null  object
#  7   Category          12006 non-null  object
#  8   Manufacturerdesc  12237 non-null  object
#  9   Branddesc         12237 non-null  object
#  10  Sku Status        12237 non-null  object
#  11  Qty               12237 non-null  object
#  12  ABC DC            231 non-null    object
# dtypes: object(13)
# memory usage: 1.2+ MB

# %%
df = df[df['No'] != 'No']

df_1 = df.loc[:, ['No']]
df_2 = df.loc[:, ['Customer Code']]
df_3 = df.loc[:, ['Itemlink', 'Itemcode', 'Description']]
df_4 = df.loc[:, ['Category']]
df_5 = df.loc[:, ['Qty']]

df_1 = df_1.dropna().reset_index(drop=True)
df_2 = df_2.dropna().reset_index(drop=True)
df_3 = df_3.dropna().reset_index(drop=True)
df_4 = df_4.dropna().reset_index(drop=True)
df_5 = df_5.dropna().reset_index(drop=True)

df = pd.concat([df_1, df_2, df_3, df_4, df_5], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12006 entries, 0 to 12005
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   No             12006 non-null  object
#  1   Customer Code  12006 non-null  object
#  2   Itemlink       12006 non-null  object
#  3   Itemcode       12006 non-null  object
#  4   Description    12006 non-null  object
#  5   Category       12006 non-null  object
#  6   Qty            12006 non-null  object
# dtypes: object(7)
# memory usage: 656.7+ KB

# %%
df['Qty'] = df['Qty'].fillna(0).astype(int)
df.to_excel('Misaligned Data [cleaned].xlsx', index=False)
df.info()
# Out:
# C:\Users\peiyi\AppData\Local\Temp\ipykernel_14484\288708279.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Qty'] = df['Qty'].fillna(0).astype(int)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12006 entries, 0 to 12005
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   No             12006 non-null  object
#  1   Customer Code  12006 non-null  object
#  2   Itemlink       12006 non-null  object
#  3   Itemcode       12006 non-null  object
#  4   Description    12006 non-null  object
#  5   Category       12006 non-null  object
#  6   Qty            12006 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 656.7+ KB
